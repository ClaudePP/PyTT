# %% [markdown]
# plot max temperature evolution
#
# 2023.08.08, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# for WIRESCANNER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos",maxT"])
# for SEM-grid of SPLITTER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])
df = pd.read_csv("MaxTempVSTime_Emi.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])

# %%
print(df)
# Out:
#         em          time     maxT
# 0      0.4  5.000000e+02  316.862
# 1      0.4  1.000000e+03  333.635
# 2      0.4  1.500000e+03  350.319
# 3      0.4  2.000000e+03  366.916
# 4      0.4  2.500000e+03  383.418
# ...    ...           ...      ...
# 19995  0.4  9.998000e+06  388.469
# 19996  0.4  9.998500e+06  388.443
# 19997  0.4  9.999000e+06  388.418
# 19998  0.4  9.999500e+06  388.392
# 19999  0.4  1.000000e+07  388.367
#
# [20000 rows x 3 columns]

# %%
plt.plot([x/1e6 for x in df["time"]],df["maxT"])
plt.xlabel("time [s]")
# Out:
# Text(0.5, 0, 'time [s]')
