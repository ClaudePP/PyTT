# %% [markdown]
# plot max temperature evolution
#
# 2023.08.08, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# for WIRESCANNER
df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos","maxT"])
# for SEM-grid of SPLITTER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])

# %%
print(df)
# Out:
#              em           time       pos      maxT
# 0      0.060000       9.866667 -2.960000   300.000
# 1      0.060000      19.733333 -2.959941   300.000
# 2      0.060000      29.600000 -2.959882   300.000
# 3      0.060000      39.466667 -2.959822   300.000
# 4      0.060000      49.333333 -2.959763   300.000
# ...         ...            ...       ...       ...
# 99995  0.129834  986627.200002  2.959704  1220.981
# 99996  0.129832  986637.066668  2.959763  1220.972
# 99997  0.129831  986646.933335  2.959822  1220.964
# 99998  0.129830  986656.800002  2.959882  1220.955
# 99999  0.129829  986666.666668  2.959941  1220.946
#
# [100000 rows x 4 columns]

# %%
plt.plot([x/1e6 for x in df["time"]],df["maxT"])
plt.xlabel("time [s]")
plt.ylabel("temperature [K]")
# Out:
# Text(0, 0.5, 'temperature [K]')
