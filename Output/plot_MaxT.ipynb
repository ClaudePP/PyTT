# %% [markdown]
# plot max temperature evolution
#
# 2023.08.08, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# for WIRESCANNER
df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos","maxT"])
# for SEM-grid of SPLITTER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])

# %%
print(df)
# Out:
#         em         time       pos      maxT
# 0      0.8     0.050111 -0.180000   301.148
# 1      0.8     0.100222 -0.179955   302.299
# 2      0.8     0.150333 -0.179910   303.453
# 3      0.8     0.200444 -0.179865   304.611
# 4      0.8     0.250556 -0.179820   305.772
# ...    ...          ...       ...       ...
# 99995  0.8  5010.910667  4.329774  1937.243
# 99996  0.8  5010.960778  4.329820  1937.239
# 99997  0.8  5011.010889  4.329865  1937.234
# 99998  0.8  5011.061000  4.329910  1937.229
# 99999  0.8  5011.111111  4.329955  1937.225
#
# [100000 rows x 4 columns]

# %%
plt.plot([x/1e6 for x in df["time"]],df["maxT"])
plt.xlabel("time [s]")
plt.ylabel("temperature [K]")
# Out:
# Text(0, 0.5, 'temperature [K]')
