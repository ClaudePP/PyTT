# %% [markdown]
# plot max temperature evolution
#
# 2023.08.08, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos","maxT"])

# %%
print(df)
# Out:
#         em          time       pos    maxT
# 0      0.8  3.986532e+01 -2.959941  1030.0
# 1      0.8  5.979798e+01 -2.959882  1030.0
# 2      0.8  7.973064e+01 -2.959822  1030.0
# 3      0.8  9.966330e+01 -2.959763  1030.0
# 4      0.8  1.195960e+02 -2.959704  1030.0
# ...    ...           ...       ...     ...
# 99994  0.8  1.993186e+06  2.959704  1030.0
# 99995  0.8  1.993206e+06  2.959763  1030.0
# 99996  0.8  1.993226e+06  2.959822  1030.0
# 99997  0.8  1.993246e+06  2.959882  1030.0
# 99998  0.8  1.993266e+06  2.959941  1030.0
#
# [99999 rows x 4 columns]

# %%
plt.plot(df["pos"],df["maxT"])
