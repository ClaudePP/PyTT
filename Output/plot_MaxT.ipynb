# %% [markdown]
# plot max temperature evolution
#
# 2023.08.08, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# for WIRESCANNER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos",maxT"])
# for SEM-grid of SPLITTER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])
df = pd.read_csv("MaxTempVSTime_Emi.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])

# %%
print(df)
# Out:
#           em          time     maxT
# 0        0.8  0.000000e+00  300.000
# 1        0.8  1.000000e+00  302.272
# 2        0.8  2.000000e+00  304.543
# 3        0.8  3.000000e+00  306.815
# 4        0.8  4.000000e+00  309.087
# ...      ...           ...      ...
# 9999995  0.8  9.999995e+06  351.027
# 9999996  0.8  9.999996e+06  351.027
# 9999997  0.8  9.999997e+06  351.027
# 9999998  0.8  9.999998e+06  351.027
# 9999999  0.8  9.999999e+06  351.027
#
# [10000000 rows x 3 columns]

# %%
plt.plot([x/1e6 for x in df["time"]],df["maxT"])
plt.xlabel("time [s]")
# Out:
# Text(0.5, 0, 'time [s]')
