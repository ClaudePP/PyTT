# %% [markdown]
# plot max temperature evolution
#
# 2023.08.08, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# for WIRESCANNER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos","maxT"])
# for SEM-grid of SPLITTER
df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])

# %%
print(df)
# Out:
#        em      time     maxT
# 0     0.4       0.0  300.000
# 1     0.4     100.0  300.060
# 2     0.4     200.0  300.119
# 3     0.4     300.0  300.179
# 4     0.4     400.0  300.239
# ...   ...       ...      ...
# 9995  0.4  999500.0  817.265
# 9996  0.4  999600.0  817.305
# 9997  0.4  999700.0  817.345
# 9998  0.4  999800.0  817.385
# 9999  0.4  999900.0  817.425
#
# [10000 rows x 3 columns]

# %%
plt.plot([x/1e6 for x in df["time"]],df["maxT"])
plt.xlabel("time [s]")
plt.ylabel("temperature [K]")
# Out:
# Text(0, 0.5, 'temperature [K]')
