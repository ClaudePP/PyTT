# %% [markdown]
# plot results of SEM grid simulations: max temperature and currents
#
# 2025.02.01, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

from platform import python_version
print("python version: ",python_version())
#matplotlib notebook
# %matplotlib inline
# Out:
# python version:  3.13.1

# %%
#df = pd.read_csv("Last.txt", skiprows=9)
#df = pd.read_csv("Last_TATTOOS_Mo100um_100uA.txt", skiprows=9)
#df = pd.read_csv("Last_TATTOOS_W100um_100uA.txt", skiprows=9)
df = pd.read_csv("Last_TATTOOS_W100um_70uA.txt", skiprows=9)

#df = pd.read_csv("Last_UCN_harp_Mo40um_1p9mA.txt", skiprows=9)

# %%
print(df)
# Out:
#        Time[us]        Npart0        Npart1        Npart2  MaxTemp0[K]  \
# 0           0.0  3.191659e+09  3.485941e+09  3.191659e+09        300.5
# 1        1000.0  3.191659e+09  3.485941e+09  3.191659e+09        301.1
# 2        2000.0  3.191659e+09  3.485941e+09  3.191659e+09        301.6
# 3        3000.0  3.191659e+09  3.485941e+09  3.191659e+09        302.2
# 4        4000.0  3.191659e+09  3.485941e+09  3.191659e+09        302.7
# ...         ...           ...           ...           ...          ...
# 3328  3328000.0  3.191659e+09  3.485941e+09  3.191659e+09       1291.4
# 3329  3329000.0  3.191659e+09  3.485941e+09  3.191659e+09       1291.5
# 3330  3330000.0  3.191659e+09  3.485941e+09  3.191659e+09       1291.5
# 3331  3331000.0  3.191659e+09  3.485941e+09  3.191659e+09       1291.5
# 3332  3332000.0  3.191659e+09  3.485941e+09  3.191659e+09          1.0
#
#       MaxTemp1[K]  MaxTemp2[K]  SEMcurr0[uA]  SEMcurr1[uA]  SEMcurr2[uA]  \
# 0           300.6        300.5       0.02828      0.030888       0.02828
# 1           301.2        301.1       0.02828      0.030888       0.02828
# 2           301.8        301.6       0.02828      0.030888       0.02828
# 3           302.4        302.2       0.02828      0.030888       0.02828
# 4           303.0        302.7       0.02828      0.030888       0.02828
# ...           ...          ...           ...           ...           ...
# 3328       1320.4       1291.4       0.02828      0.030888       0.02828
# 3329       1320.5       1291.5       0.02828      0.030888       0.02828
# 3330       1320.5       1291.5       0.02828      0.030888       0.02828
# 3331       1320.5       1291.5       0.02828      0.030888       0.02828
# 3332          1.0          1.0       0.02828      0.030888       0.02828
#
#       THcurrTHcurr0[uA]   THcurr1[uA]   THcurr2[uA]  Unnamed: 13
# 0          4.604368e-64  4.645175e-64  4.604368e-64          NaN
# 1          5.097752e-64  5.202205e-64  5.097752e-64          NaN
# 2          5.723988e-64  5.925785e-64  5.723988e-64          NaN
# 3          6.523201e-64  6.871688e-64  6.523201e-64          NaN
# 4          7.548106e-64  8.115070e-64  7.548106e-64          NaN
# ...                 ...           ...           ...          ...
# 3328       6.692345e-06  1.767465e-05  6.692345e-06          NaN
# 3329       6.700414e-06  1.769037e-05  6.700414e-06          NaN
# 3330       6.708479e-06  1.770609e-05  6.708479e-06          NaN
# 3331       6.716541e-06  1.772179e-05  6.716541e-06          NaN
# 3332       6.724600e-06  1.773748e-05  6.724600e-06          NaN
#
# [3333 rows x 14 columns]

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp1[K]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp0[K]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Maximum Wire Temperature [K]")
plt.legend()
#plt.text(1.5,850,r"wire: Mo, $\rm 40 \mu m$")
plt.text(1.5,850,r"wire: W, $\rm 100~\mu m$")
#plt.text(1.5,750,r"beam current: $\rm 100 \mu A$")
plt.text(1.5,750,r"beam current: $\rm~70 \mu A$")
plt.text(1.5,650,r"beam sigma: 5 mm")
plt.grid()
#plt.savefig("UCN_harp_temp_evol")
plt.savefig("TATTOOS_W100um_70uA_5mm.png")

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr1[uA]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr0[uA]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Secondary Electron Current [uA]")
plt.legend()
