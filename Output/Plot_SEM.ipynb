# %% [markdown]
# plot results of SEM grid simulations: max temperature and currents
#
# 2025.02.01, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

from platform import python_version
print("python version: ",python_version())
#matplotlib notebook
# %matplotlib inline
# Out:
# python version:  3.13.1

# %%
df = pd.read_csv("Last.txt", skiprows=9)

# %%
print(df)
# Out:
#        Time[us]        Npart0        Npart1        Npart2  MaxTemp0[K]  \
# 0           0.0  3.402596e+09  3.485941e+09  3.402596e+09        300.6
# 1        1000.0  3.402596e+09  3.485941e+09  3.402596e+09        301.2
# 2        2000.0  3.402596e+09  3.485941e+09  3.402596e+09        301.7
# 3        3000.0  3.402596e+09  3.485941e+09  3.402596e+09        302.3
# 4        4000.0  3.402596e+09  3.485941e+09  3.402596e+09        302.9
# ...         ...           ...           ...           ...          ...
# 3328  3328000.0  3.402596e+09  3.485941e+09  3.402596e+09       1125.5
# 3329  3329000.0  3.402596e+09  3.485941e+09  3.402596e+09       1125.6
# 3330  3330000.0  3.402596e+09  3.485941e+09  3.402596e+09       1125.6
# 3331  3331000.0  3.402596e+09  3.485941e+09  3.402596e+09       1125.6
# 3332  3332000.0  3.402596e+09  3.485941e+09  3.402596e+09          1.0
#
#       MaxTemp1[K]  MaxTemp2[K]  SEMcurr0[uA]  SEMcurr1[uA]  SEMcurr2[uA]  \
# 0           300.6        300.6       0.03015      0.030888       0.03015
# 1           301.2        301.2       0.03015      0.030888       0.03015
# 2           301.8        301.7       0.03015      0.030888       0.03015
# 3           302.4        302.3       0.03015      0.030888       0.03015
# 4           303.0        302.9       0.03015      0.030888       0.03015
# ...           ...          ...           ...           ...           ...
# 3328       1133.1       1125.5       0.03015      0.030888       0.03015
# 3329       1133.1       1125.6       0.03015      0.030888       0.03015
# 3330       1133.1       1125.6       0.03015      0.030888       0.03015
# 3331       1133.1       1125.6       0.03015      0.030888       0.03015
# 3332          1.0          1.0       0.03015      0.030888       0.03015
#
#       THcurrTHcurr0[uA]   THcurr1[uA]   THcurr2[uA]  Unnamed: 13
# 0          4.633529e-64  4.645175e-64  4.633529e-64          NaN
# 1          5.172134e-64  5.202184e-64  5.172134e-64          NaN
# 2          5.867163e-64  5.925705e-64  5.867163e-64          NaN
# 3          6.769513e-64  6.871477e-64  6.769513e-64          NaN
# 4          7.947266e-64  8.114606e-64  7.947266e-64          NaN
# ...                 ...           ...           ...          ...
# 3328       1.226248e-08  1.700801e-08  1.226248e-08          NaN
# 3329       1.227059e-08  1.701839e-08  1.227059e-08          NaN
# 3330       1.227870e-08  1.702875e-08  1.227870e-08          NaN
# 3331       1.228679e-08  1.703911e-08  1.228679e-08          NaN
# 3332       1.229488e-08  1.704945e-08  1.229488e-08          NaN
#
# [3333 rows x 14 columns]

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp1[K]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp0[K]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Maximum Wire Temperature [K]")
plt.legend()
plt.grid()

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr1[uA]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr0[uA]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Secondary Electron Current [uA]")
plt.legend()
