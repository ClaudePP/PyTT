# %% [markdown]
# plot results of SEM grid simulations: max temperature and currents
#
# 2025.02.01, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

from platform import python_version
print("python version: ",python_version())
#matplotlib notebook
# %matplotlib inline
# Out:
# python version:  3.13.1

# %%
#df = pd.read_csv("Last.txt", skiprows=9)
#df = pd.read_csv("Last_TATTOOS_Mo100um_100uA.txt", skiprows=9)
#df = pd.read_csv("Last_TATTOOS_W100um_100uA.txt", skiprows=9)
#df = pd.read_csv("Last_TATTOOS_W100um_70uA.txt", skiprows=9)

#df = pd.read_csv("Last_UCN_harp_Mo40um_1p9mA.txt", skiprows=9)
df = pd.read_csv("Last_NorthStar.txt", skiprows=9)

# %%
print(df)
# Out:
#        Time[us]        Npart0        Npart1        Npart2  MaxTemp0[K]  \
# 0           0.0  9.321450e+09  4.026373e+10  9.321450e+09        302.7
# 1        1000.0  9.321450e+09  4.026373e+10  9.321450e+09        305.3
# 2        2000.0  9.321450e+09  4.026373e+10  9.321450e+09        307.9
# 3        3000.0  9.321450e+09  4.026373e+10  9.321450e+09        310.6
# 4        4000.0  9.321450e+09  4.026373e+10  9.321450e+09        313.2
# ...         ...           ...           ...           ...          ...
# 3328  3328000.0  9.321450e+09  4.026373e+10  9.321450e+09       1607.4
# 3329  3329000.0  9.321450e+09  4.026373e+10  9.321450e+09       1607.4
# 3330  3330000.0  9.321450e+09  4.026373e+10  9.321450e+09       1607.4
# 3331  3331000.0  9.321450e+09  4.026373e+10  9.321450e+09       1607.4
# 3332  3332000.0  9.321450e+09  4.026373e+10  9.321450e+09          1.0
#
#       MaxTemp1[K]  MaxTemp2[K]  SEMcurr0[uA]  SEMcurr1[uA]  SEMcurr2[uA]  \
# 0           311.4        302.7      0.061109      0.263961      0.061109
# 1           322.8        305.3      0.061109      0.263961      0.061109
# 2           334.2        307.9      0.061109      0.263961      0.061109
# 3           345.4        310.6      0.061109      0.263961      0.061109
# 4           356.6        313.2      0.061109      0.263961      0.061109
# ...           ...          ...           ...           ...           ...
# 3328       2157.1       1607.4      0.061109      0.263961      0.061109
# 3329       2157.1       1607.4      0.061109      0.263961      0.061109
# 3330       2157.1       1607.4      0.061109      0.263961      0.061109
# 3331       2157.1       1607.4      0.061109      0.263961      0.061109
# 3332          1.0          1.0      0.061109      0.263961      0.061109
#
#       THcurrTHcurr0[uA]   THcurr1[uA]   THcurr2[uA]  Unnamed: 13
# 0          5.846148e-71  3.777283e-69  5.846148e-71          NaN
# 1          1.600343e-70  1.863217e-66  1.600343e-70          NaN
# 2          5.805521e-70  6.781848e-64  5.805521e-70          NaN
# 3          2.369721e-69  1.715113e-61  2.369721e-69          NaN
# 4          1.002019e-68  3.055991e-59  1.002019e-68          NaN
# ...                 ...           ...           ...          ...
# 3328       8.860285e-04  1.502792e+01  8.860285e-04          NaN
# 3329       8.860285e-04  1.502792e+01  8.860285e-04          NaN
# 3330       8.860285e-04  1.502792e+01  8.860285e-04          NaN
# 3331       8.860285e-04  1.502792e+01  8.860285e-04          NaN
# 3332       8.860286e-04  1.502792e+01  8.860286e-04          NaN
#
# [3333 rows x 14 columns]

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp1[K]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp0[K]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Maximum Wire Temperature [K]")
plt.legend()
plt.text(1.5,850,r"wire: Mo, $\rm 40 \mu m$")
#plt.text(1.5,850,r"wire: Mo, $\rm 100~\mu m$")
#plt.text(1.5,750,r"beam current: $\rm 100 \mu A$")
plt.text(1.5,750,r"beam current: $\rm~1.9~mA$")
plt.text(1.5,650,r"beam sigma: 4.7 mm")
plt.grid()
plt.savefig("UCN_harp_temp_evol")
#plt.savefig("TATTOOS_Mo100um_100uA_3mm.png")

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr1[uA]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr0[uA]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Secondary Electron Current [uA]")
plt.legend()
