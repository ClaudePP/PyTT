# %% [markdown]
# plot results of SEM grid simulations: max temperature and currents
#
# 2025.02.01, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

from platform import python_version
print("python version: ",python_version())
#matplotlib notebook
# %matplotlib inline
# Out:
# python version:  3.13.1

# %%
#df = pd.read_csv("Last.txt", skiprows=9)
#df = pd.read_csv("Last_TATTOOS_Mo100um_100uA.txt", skiprows=9)
#df = pd.read_csv("Last_TATTOOS_W100um_100uA.txt", skiprows=9)
df = pd.read_csv("Last_UCN_harp_Mo40um_1p9mA.txt", skiprows=9)

# %%
print(df)
# Out:
#        Time[us]        Npart0        Npart1        Npart2  MaxTemp0[K]  \
# 0           0.0  3.857284e+10  4.238287e+10  3.857284e+10        311.0
# 1        1000.0  3.857284e+10  4.238287e+10  3.857284e+10        321.9
# 2        2000.0  3.857284e+10  4.238287e+10  3.857284e+10        332.7
# 3        3000.0  3.857284e+10  4.238287e+10  3.857284e+10        343.5
# 4        4000.0  3.857284e+10  4.238287e+10  3.857284e+10        354.3
# ...         ...           ...           ...           ...          ...
# 3328  3328000.0  3.857284e+10  4.238287e+10  3.857284e+10       2139.0
# 3329  3329000.0  3.857284e+10  4.238287e+10  3.857284e+10       2139.0
# 3330  3330000.0  3.857284e+10  4.238287e+10  3.857284e+10       2139.0
# 3331  3331000.0  3.857284e+10  4.238287e+10  3.857284e+10       2139.0
# 3332  3332000.0  3.857284e+10  4.238287e+10  3.857284e+10          1.0
#
#       MaxTemp1[K]  MaxTemp2[K]  SEMcurr0[uA]  SEMcurr1[uA]  SEMcurr2[uA]  \
# 0           312.1        311.0      0.252875      0.277853      0.252875
# 1           324.0        321.9      0.252875      0.277853      0.252875
# 2           335.9        332.7      0.252875      0.277853      0.252875
# 3           347.8        343.5      0.252875      0.277853      0.252875
# 4           359.6        354.3      0.252875      0.277853      0.252875
# ...           ...          ...           ...           ...           ...
# 3328       2178.9       2139.0      0.252875      0.277853      0.252875
# 3329       2178.9       2139.0      0.252875      0.277853      0.252875
# 3330       2178.9       2139.0      0.252875      0.277853      0.252875
# 3331       2178.9       2139.0      0.252875      0.277853      0.252875
# 3332          1.0          1.0      0.252875      0.277853      0.252875
#
#       THcurrTHcurr0[uA]   THcurr1[uA]   THcurr2[uA]  Unnamed: 13
# 0          2.907192e-69  5.249174e-69  2.907192e-69          NaN
# 1          1.116180e-66  3.529916e-66  1.116180e-66          NaN
# 2          3.286349e-64  1.667921e-63  3.286349e-64          NaN
# 3          6.928607e-62  5.268263e-61  6.928607e-62          NaN
# 4          1.055707e-59  1.135007e-58  1.055707e-59          NaN
# ...                 ...           ...           ...          ...
# 3328       1.177761e+01  2.006163e+01  1.177761e+01          NaN
# 3329       1.177761e+01  2.006163e+01  1.177761e+01          NaN
# 3330       1.177761e+01  2.006163e+01  1.177761e+01          NaN
# 3331       1.177761e+01  2.006163e+01  1.177761e+01          NaN
# 3332       1.177761e+01  2.006163e+01  1.177761e+01          NaN
#
# [3333 rows x 14 columns]

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp1[K]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["MaxTemp0[K]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Maximum Wire Temperature [K]")
plt.legend()
plt.text(1.5,850,r"wire: Mo, $\rm 40 \mu m$")
#plt.text(1.5,750,r"beam current: $\rm 100 \mu A$")
plt.text(1.5,750,r"beam current: $\rm 2 mA$")
plt.text(1.5,650,r"beam sigma: 4.6 mm")
plt.grid()
plt.savefig("TATTOOS_harp_temp_evol")

# %%
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr1[uA]"][:-1],label="central wire")
plt.plot([x*1e-6 for x in df["Time[us]"][:-1]],df["SEMcurr0[uA]"][:-1],label="side wire")
plt.xlabel("Time [s]")
plt.ylabel("Secondary Electron Current [uA]")
plt.legend()
