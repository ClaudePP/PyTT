# %% [markdown]
# plot max temperature evolution AND beam profile AND SEM+Thermionic emission
#
# 2024.03.27, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# for WIRESCANNER option output only
dft = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos","maxT"])
dfc = pd.read_csv("IntensityVSTime.txt", skiprows=3, delim_whitespace=True, names=["time","pos","curr"])

# %%
print(dfc)
# Out:
#                 time   pos          curr
# 0           9.866667 -2.96  9.513575e-10
# 1          19.733333 -2.96  9.517913e-10
# 2          29.600000 -2.96  9.522252e-10
# 3          39.466667 -2.96  9.526594e-10
# 4          49.333333 -2.96  9.530937e-10
# ...              ...   ...           ...
# 99995  986627.200002  2.96  9.452774e-09
# 99996  986637.066668  2.96  9.450009e-09
# 99997  986646.933335  2.96  9.447245e-09
# 99998  986656.800002  2.96  9.444481e-09
# 99999  986666.666668  2.96  9.441719e-09
#
# [100000 rows x 3 columns]

# %%
plt.plot([x*10 for x in dft["pos"]],dft["maxT"])
#plt.xlabel("time [s]")
plt.xlabel("position [mm]")
plt.ylabel("max temperature [K]")
# Out:
# Text(0, 0.5, 'max temperature [K]')
