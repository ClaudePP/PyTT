# %% [markdown]
# plot max temperature evolution
#
# 2023.08.08, mariusz.sapinski@psi.ch

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# for WIRESCANNER
df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","pos","maxT"])
# for SEM-grid of SPLITTER
#df = pd.read_csv("MaxTempVSTime.txt", skiprows=3, delim_whitespace=True, names=["em","time","maxT"])

# %%
print(df)
# Out:
#         em       time       pos      maxT
# 0      0.8      0.451 -0.180000   301.174
# 1      0.8      0.902 -0.179955   302.351
# 2      0.8      1.353 -0.179910   303.532
# 3      0.8      1.804 -0.179865   304.716
# 4      0.8      2.255 -0.179820   305.903
# ...    ...        ...       ...       ...
# 99995  0.8  45098.196  4.329774  1052.098
# 99996  0.8  45098.647  4.329820  1052.095
# 99997  0.8  45099.098  4.329865  1052.091
# 99998  0.8  45099.549  4.329910  1052.087
# 99999  0.8  45100.000  4.329955  1052.084
#
# [100000 rows x 4 columns]

# %%
plt.plot([x/1e6 for x in df["time"]],df["maxT"])
plt.xlabel("time [s]")
plt.ylabel("temperature [K]")
# Out:
# Text(0.5, 0, 'time [s]')
